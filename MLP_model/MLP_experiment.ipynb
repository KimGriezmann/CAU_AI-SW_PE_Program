# %% [markdown]
# <a href="https://colab.research.google.com/github/KimGriezmann/DeepLearning_BeTheLegend/blob/master/MLP_model/MLP_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **2018-21시즌 데이터를 사용한 MLP model**
# ### Number of data = *29395*
# 선발 출전한 선수\
# 3월, 4월 데이터 제외\
# 0타수인 데이터 제외\
# avLI, RE24, WPA feature 추가\
# Validation data set 추가\
# loss & acc graph
# ### Number of feature = *13*
#
# 1. avg (타율)
# 2. slg (장타율)
# 3. ops (출루율 + 장타율)
# 4. home/away_avg_y (홈/원정 별 타율)
# 5. avLI
# 6. RE24
# 7. WPA
# 8. vs_avg (상대 팀 타율)
# 9. recent_5days_avg (최근 5일 타율)
# 10. recent_5games_avg (최근 5경기 타율)
# 11. recent_10games_avg (최근 10경기 타율)
# 12. success_10days (최근 10일 성공률)
# 13. success_10games (최근 10경기 성공률)
#
# acc = 0.8127

# %%
import numpy as np
import pandas as pd
import tqdm
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
final_2018_2021 = pd.read_csv('/content/drive/MyDrive/bethelegend/final_2018_2021.csv', encoding='euc-kr')

# %%
final_2018_2021
# Out:
#       name   day   vs  ... recent_10games_avg  success_10days success_10games
# 0      강백호   404   한화  ...           0.000000        0.000000        0.000000
# 1      강백호   406   LG  ...           0.666667        1.000000        1.000000
# 2      강백호   407   LG  ...           0.285714        0.500000        0.500000
# 3      강백호   408   LG  ...           0.454545        0.666667        0.666667
# 4      강백호   409  @삼성  ...           0.466667        0.750000        0.750000
# ...    ...   ...  ...  ...                ...             ...             ...
# 39113  강경학  1006  @롯데  ...           0.200000        0.500000        0.400000
# 39114  강경학  1009  @KT  ...           0.222222        0.333333        0.400000
# 39115  강경학  1019   넥센  ...           0.235294        1.000000        0.400000
# 39116  강경학  1020   넥센  ...           0.235294        0.000000        0.400000
# 39117  강경학  1023  @넥센  ...           0.176471        0.000000        0.300000
#
# [39118 rows x 58 columns]

# %%
sns.countplot(final_2018_2021['ab'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#선발 출장에 한정
final_2018_2021 = final_2018_2021[final_2018_2021['start_member'] == 1]

# %%
#3월, 4월 데이터 제외
final_2018_2021 = final_2018_2021.loc[final_2018_2021['day']>= 500]

# %%
#0타수 데이터 제외
final_2018_2021 = final_2018_2021[final_2018_2021['ab']>0]

# %%
final_2018_2021
# Out:
#       name  day   vs  ... recent_10games_avg  success_10days success_10games
# 23     강백호  501  KIA  ...           0.428571        0.000000             1.0
# 24     강백호  502  KIA  ...           0.463415        1.000000             1.0
# 25     강백호  505  @키움  ...           0.450000        1.000000             1.0
# 26     강백호  506  @키움  ...           0.473684        1.000000             1.0
# 27     강백호  508   NC  ...           0.405405        0.750000             0.9
# ...    ...  ...  ...  ...                ...             ...             ...
# 39103  강경학  916   LG  ...           0.166667        0.375000             0.4
# 39104  강경학  918  @NC  ...           0.120000        0.142857             0.3
# 39107  강경학  923  KIA  ...           0.130435        0.500000             0.3
# 39108  강경학  925   삼성  ...           0.160000        0.600000             0.4
# 39109  강경학  926   삼성  ...           0.173913        0.500000             0.4
#
# [29395 rows x 58 columns]

# %% [markdown]
# ### **Multi layer Perceptron in Be the legend**

# %%
mlp_data = final_2018_2021.loc[:, ['name', 'day', 'start_member', 'vs_team', 'avg', 'slg', 'ops', 'avLI', 'RE24', 'WPA', 'home/away_avg_y', 'vs_ab', 'vs_hit', 'vs_avg', 'recent_5days_avg', 'recent_5games_avg', 'recent_10games_avg', 'success_10days', 'success_10games', 'result_y']]

# %%
mlp_data

# %%
len(mlp_data)
# Out:
# 29395

# %%
len(mlp_data[mlp_data['result_y'] == 1]) / len(mlp_data) * 100
# Out:
# 67.47065827521688

# %%
from keras.utils.np_utils import to_categorical
import numpy as np
from sklearn.preprocessing import minmax_scale
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **Training data set / Test data set 분할**

# %%
mlp_train, mlp_test = train_test_split(mlp_data, test_size=0.3, random_state=50)

# %%
#현재 가지고 있는 모든 피쳐 사용

X_train = mlp_train.loc[:, ['avg', 'slg', 'ops', 'avLI', 'RE24', 'WPA', 'home/away_avg_y', 'vs_avg', 'recent_5days_avg', 'recent_5games_avg', 'recent_10games_avg', 'success_10days', 'success_10games']]
y_train = mlp_train.loc[:, ['result_y']]

X_test = mlp_test.loc[:, ['avg', 'slg', 'ops', 'avLI', 'RE24', 'WPA', 'home/away_avg_y', 'vs_avg', 'recent_5days_avg', 'recent_5games_avg', 'recent_10games_avg', 'success_10days', 'success_10games']]
y_test = mlp_test.loc[:, ['result_y']]

# %%
#홈/원정 타율, 상대 타율, 최근 5일 타율, 최근 5게임 타율, 최근 10게임 타율, 최근 10일 성공률, 최근 10경기 성공률 사용

# X_train = mlp_train.loc[:, ['home/away_avg_y', 'vs_avg', 'recent_5days_avg', 'recent_5games_avg', 'recent_10games_avg', 'success_10days', 'success_10games']]
# y_train = mlp_train.loc[:, ['result_y']]

# X_test = mlp_test.loc[:, ['home/away_avg_y', 'vs_avg', 'recent_5days_avg', 'recent_5games_avg', 'recent_10games_avg', 'success_10days', 'success_10games']]
# y_test = mlp_test.loc[:, ['result_y']]

# %%
#홈/원정 타율, 상대 타율, 최근 5일 타율, 최근 5게임 타율, 최근 10게임 타율

# X_train = mlp_train.loc[:, ['home/away_avg_y', 'vs_avg', 'recent_5days_avg', 'recent_5games_avg', 'recent_10games_avg']]
# y_train = mlp_train.loc[:, ['result_y']]

# X_test = mlp_test.loc[:, ['home/away_avg_y', 'vs_avg', 'recent_5days_avg', 'recent_5games_avg', 'recent_10games_avg']]
# y_test = mlp_test.loc[:, ['result_y']]

# %%
X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

# %%
number_of_train_samples = X_train.shape[0]
width = X_train.shape[1]
X_train = X_train.reshape(number_of_train_samples, width)

# %%
number_of_test_samples = X_test.shape[0]
X_test = X_test.reshape(number_of_test_samples, width)

# %%
X_train = minmax_scale(X_train, feature_range=(0,1), axis = 0)
X_test = minmax_scale(X_test, feature_range=(0,1), axis = 0)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### **Validation data set / Training data set 분할**

# %%
X_val = X_train[:5000]
X_train = X_train[5000:]

y_val = y_train[:5000]
y_train = y_train[5000:]

# %% [markdown]
# ### **MLP Model**

# %%
#Activation = Relu & Sigmoid 
#Loss = 0.4036 - Accuracy = 0.8127
model = Sequential()

model.add(Dense(32, input_dim= width, kernel_initializer = 'glorot_uniform', activation = 'relu'))

# model.add(Dense(96, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(48, activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))

# %%
#loss: 0.4012 - acc: 0.8142
model = Sequential()

model.add(Dense(16, input_dim= width, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))

# %%
#loss: 0.4051 - acc: 0.8131
model = Sequential()

model.add(Dense(16, input_dim= width, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))

# %%
#loss: 0.4387 - acc: 0.8118
model = Sequential()

model.add(Dense(64, input_dim= width, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))

# %%
#loss: 0.3979 - acc: 0.8148 (loss function: binary_crossentrophy, optimizer : rmsprop)
#loss: 0.1295 - acc: 0.8165 (loss function: mean_squared_error, optimizer : Adam)
model = Sequential()

model.add(Dense(32, input_dim= width, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))

# %%
#loss: 0.1306 - acc: 0.8136 (loss function: mean_squared_error, optimizer: rmsprop, batch_size: 32)
model = Sequential()

model.add(Dense(32, input_dim= width, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(16, input_dim= width, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))

# %%
# loss: 0.4701 - acc: 0.8083 (loss function: binary_crossentrophy, optimizer : rmsprop, batch_size: 32)
# loss: 0.1391 - acc: 0.8100 (loss function: mean_squared_error, optimizer : rmsprop, batch_size: 32)
model = Sequential()

model.add(Dense(64, input_dim= width, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))

# %%
# loss: 0.1287 - acc: 0.8178 (loss function: mean_squared_error, optimizer : Adam, batch_size: 64)
model = Sequential()

model.add(Dense(64, input_dim= width, kernel_initializer = 'HeNormal', activation = 'relu'))
# model.add(Dense(64, kernel_initializer = 'HeNormal', activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))

# %%
# loss: 0.1327 - acc: 0.8101 (loss function: mean_squared_error, optimizer : rmsprop, batch_size: 32)
model = Sequential()

model.add(Dense(64, input_dim= width, kernel_initializer = 'HeNormal', activation = 'relu'))
model.add(Dense(64, kernel_initializer = 'HeNormal', activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))

# %%
#Activation = Sigmoid
model = Sequential()

model.add(Dense(512, input_dim= width, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))
# model.add(Dropout(0.3))
model.add(Dense(300, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))
model.add(Dense(256, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

model.add(Dense(128, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

model.add(Dense(64, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

model.add(Dense(32, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))
model.add(Dense(16, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))
model.add(Dense(2, activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %% [markdown]
# ### **Model training**

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'rmsprop', metrics=['acc'])

history = model.fit(X_train, y_train, epochs = 200, batch_size = 32, validation_data=(X_val, y_val))
history_dict = history.history
history_dict.keys()

# %%
model.compile(loss = 'mean_squared_error', optimizer = 'Adam', metrics=['acc'])

history = model.fit(X_train, y_train, epochs = 100, batch_size = 64, validation_data=(X_val, y_val))
history_dict = history.history
history_dict.keys()

# %%
model.compile(loss = 'mean_squared_error', optimizer = 'rmsprop', metrics=['acc'])

history = model.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_data=(X_val, y_val))
history_dict = history.history
history_dict.keys()
# Out:
# Epoch 1/100
# 487/487 [==============================] - 2s 2ms/step - loss: 0.2035 - acc: 0.6680 - val_loss: 0.1636 - val_acc: 0.7258
# Epoch 2/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1618 - acc: 0.7522 - val_loss: 0.1405 - val_acc: 0.8028
# Epoch 3/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1452 - acc: 0.7858 - val_loss: 0.1357 - val_acc: 0.8028
# Epoch 4/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1410 - acc: 0.7941 - val_loss: 0.1335 - val_acc: 0.8080
# Epoch 5/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1441 - acc: 0.7911 - val_loss: 0.1341 - val_acc: 0.8086
# Epoch 6/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1422 - acc: 0.7929 - val_loss: 0.1401 - val_acc: 0.7984
# Epoch 7/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1394 - acc: 0.7995 - val_loss: 0.1330 - val_acc: 0.8118
# Epoch 8/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1436 - acc: 0.7921 - val_loss: 0.1352 - val_acc: 0.8036
# Epoch 9/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1393 - acc: 0.7981 - val_loss: 0.1314 - val_acc: 0.8136
# Epoch 10/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1411 - acc: 0.7961 - val_loss: 0.1361 - val_acc: 0.8028
# Epoch 11/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1356 - acc: 0.8057 - val_loss: 0.1376 - val_acc: 0.8038
# Epoch 12/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1365 - acc: 0.8045 - val_loss: 0.1398 - val_acc: 0.7934
# Epoch 13/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1369 - acc: 0.8032 - val_loss: 0.1393 - val_acc: 0.7966
# Epoch 14/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1362 - acc: 0.8042 - val_loss: 0.1417 - val_acc: 0.7946
# Epoch 15/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1416 - acc: 0.7948 - val_loss: 0.1335 - val_acc: 0.8084
# Epoch 16/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1397 - acc: 0.7999 - val_loss: 0.1352 - val_acc: 0.8042
# Epoch 17/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.
100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1326 - acc: 0.8118 - val_loss: 0.1321 - val_acc: 0.8078
# Epoch 84/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1332 - acc: 0.8091 - val_loss: 0.1308 - val_acc: 0.8134
# Epoch 85/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1349 - acc: 0.8078 - val_loss: 0.1312 - val_acc: 0.8116
# Epoch 86/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1292 - acc: 0.8133 - val_loss: 0.1305 - val_acc: 0.8160
# Epoch 87/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1295 - acc: 0.8150 - val_loss: 0.1313 - val_acc: 0.8154
# Epoch 88/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1307 - acc: 0.8154 - val_loss: 0.1317 - val_acc: 0.8114
# Epoch 89/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1308 - acc: 0.8120 - val_loss: 0.1329 - val_acc: 0.8104
# Epoch 90/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1339 - acc: 0.8063 - val_loss: 0.1319 - val_acc: 0.8092
# Epoch 91/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1279 - acc: 0.8172 - val_loss: 0.1313 - val_acc: 0.8176
# Epoch 92/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1302 - acc: 0.8154 - val_loss: 0.1316 - val_acc: 0.8122
# Epoch 93/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1270 - acc: 0.8215 - val_loss: 0.1319 - val_acc: 0.8118
# Epoch 94/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1318 - acc: 0.8104 - val_loss: 0.1321 - val_acc: 0.8114
# Epoch 95/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1299 - acc: 0.8161 - val_loss: 0.1317 - val_acc: 0.8120
# Epoch 96/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1306 - acc: 0.8143 - val_loss: 0.1306 - val_acc: 0.8148
# Epoch 97/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1333 - acc: 0.8080 - val_loss: 0.1377 - val_acc: 0.8004
# Epoch 98/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1281 - acc: 0.8180 - val_loss: 0.1314 - val_acc: 0.8130
# Epoch 99/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1281 - acc: 0.8177 - val_loss: 0.1304 - val_acc: 0.8162
# Epoch 100/100
# 487/487 [==============================] - 1s 2ms/step - loss: 0.1278 - acc: 0.8208 - val_loss: 0.1308 - val_acc: 0.8176
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
model.compile(loss = 'mean_squared_error', optimizer = 'rmsprop', metrics=['acc'])

history = model.fit(X_train, y_train, epochs = 200, batch_size = 32, validation_data=(X_val, y_val))
history_dict = history.history
history_dict.keys()

# %% [markdown]
# ### **Graph_loss & acc**

# %%
history_dict = history.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss)+1)

plt.plot(epochs, loss, 'red', label='Training loss') 
plt.plot(epochs, val_loss, 'green', label='Validation loss')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
acc = history_dict['acc']
val_acc = history_dict['val_acc']

plt.plot(epochs, acc, 'red', label='Training acc') 
plt.plot(epochs, val_acc, 'green', label='Validation acc')
plt.title('Training & Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
#Latest try: Activation Relu & Sigmoid
loss_and_metrics = model.evaluate(X_test, y_test, batch_size = 32)
# Out:
# 276/276 [==============================] - 0s 1ms/step - loss: 0.1327 - acc: 0.8101

# %% [markdown]
# ### **otherwise**

# %%
history = model.fit(X_train, y_train, epochs= 100, batch_size = 512)

# %%
#Activation Relu & Sigmoid
loss_and_metrics = model.evaluate(X_test, y_test, batch_size = 512)
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6051 - accuracy: 0.6793

# %%
#Activation Sigmoid & Softmax
loss_and_metrics = model.evaluate(X_test, y_test, batch_size = 32)
# Out:
# 185/185 [==============================] - 1s 2ms/step - loss: 0.6350 - accuracy: 0.6693

# %%
#Activation Relu & Softmax
loss_and_metrics = model.evaluate(X_test, y_test, batch_size = 32)
# Out:
# 185/185 [==============================] - 1s 2ms/step - loss: 0.6038 - accuracy: 0.6796

# %%
len(mlp_data[mlp_data['result_y'] ==1]) / len(mlp_data) * 100
# Out:
# 67.31950714503921
