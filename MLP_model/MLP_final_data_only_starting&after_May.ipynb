# %% [markdown]
# <a href="https://colab.research.google.com/github/KimGriezmann/DeepLearning_BeTheLegend/blob/master/MLP_model/MLP_final_data_only_starting%26after_May.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **2018-21시즌 데이터를 사용한 MLP model**
# ### Number of data = *29461*
# 선발 출전한 선수
# 3월, 4월 데이터 제외
# ### Number of feature = *12*
#
# 1. avg (타율)
# 2. slg (장타율)
# 3. ops (출루율 + 장타율)
# 4. home/away_avg_y (홈/원정 별 타율)
# 5. vs_ab (상대 팀 누적 타수)
# 6. vs_hit (상대 팀 누적 안타)
# 7. vs_avg (상대 팀 타율)
# 8. recent_5days_avg (최근 5일 타율)
# 9. recent_5games_avg (최근 5경기 타율)
# 10. recent_10games_avg (최근 10경기 타율)
# 11. success_10days (최근 10일 성공률)
# 12. success_10games (최근 10경기 성공률)
#
# acc = 0.682

# %%
import numpy as np
import pandas as pd
import tqdm
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
final_2018_2021 = pd.read_csv('/content/drive/MyDrive/bethelegend/final_2018_2021.csv', encoding='euc-kr')

# %%
final_2018_2021
# Out:
#       name   day   vs  ... recent_10games_avg  success_10days success_10games
# 0      강백호   404   한화  ...           0.000000        0.000000        0.000000
# 1      강백호   406   LG  ...           0.666667        1.000000        1.000000
# 2      강백호   407   LG  ...           0.285714        0.500000        0.500000
# 3      강백호   408   LG  ...           0.454545        0.666667        0.666667
# 4      강백호   409  @삼성  ...           0.466667        0.750000        0.750000
# ...    ...   ...  ...  ...                ...             ...             ...
# 39113  강경학  1006  @롯데  ...           0.200000        0.500000        0.400000
# 39114  강경학  1009  @KT  ...           0.222222        0.333333        0.400000
# 39115  강경학  1019   넥센  ...           0.235294        1.000000        0.400000
# 39116  강경학  1020   넥센  ...           0.235294        0.000000        0.400000
# 39117  강경학  1023  @넥센  ...           0.176471        0.000000        0.300000
#
# [39118 rows x 58 columns]

# %%
sns.countplot(ex_2020_data_3['double'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#선발 출장에 한정
final_2018_2021 = final_2018_2021[final_2018_2021['start_member'] == 1]

# %%
#3월, 4월 데이터 제외
final_2018_2021 = final_2018_2021.loc[final_2018_2021['day']>= 500]

# %%
#타수가 2이상만의 데이터를 골라내는 작업
final_2018_2021 = final_2018_2021[final_2018_2021['ab']>2]

# %%
m = final_2018_2021[final_2018_2021['ab']>4]
len(m[m['result_y'] ==1]) / len(m) * 100
# Out:
# 87.98226892135939

# %%
sns.countplot(final_2018_2021['start_member'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(final_2018_2021['ab'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
final_2018_2021.loc[final_2018_2021['ab']== 1]

# %% [markdown]
# ### **Multi layer Perceptron in Be the legend**

# %%
mlp_data = final_2018_2021.loc[:, ['name', 'day', 'start_member', 'vs_team', 'avg', 'slg', 'ops', 'home/away_avg_y', 'vs_ab', 'vs_hit', 'vs_avg', 'recent_5days_avg', 'recent_5games_avg', 'recent_10games_avg', 'success_10days', 'success_10games', 'result_y']]

# %%
mlp_data
# Out:
#       name  day  start_member  ... success_10days  success_10games  result_y
# 23     강백호  501             1  ...       0.000000              1.0         1
# 24     강백호  502             1  ...       1.000000              1.0         1
# 25     강백호  505             1  ...       1.000000              1.0         1
# 26     강백호  506             1  ...       1.000000              1.0         0
# 27     강백호  508             1  ...       0.750000              0.9         1
# ...    ...  ...           ...  ...            ...              ...       ...
# 39103  강경학  916             1  ...       0.375000              0.4         0
# 39104  강경학  918             1  ...       0.142857              0.3         1
# 39107  강경학  923             1  ...       0.500000              0.3         1
# 39108  강경학  925             1  ...       0.600000              0.4         0
# 39109  강경학  926             1  ...       0.500000              0.4         0
#
# [29461 rows x 17 columns]

# %%
len(mlp_data)
# Out:
# 29461

# %%
from keras.utils.np_utils import to_categorical
import numpy as np
from sklearn.preprocessing import minmax_scale
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
mlp_train, mlp_test = train_test_split(mlp_data, test_size=0.2, random_state=50)

# %%
X_train = mlp_train.loc[:, ['avg', 'slg', 'ops', 'home/away_avg_y', 'vs_ab', 'vs_hit', 'vs_avg', 'recent_5days_avg', 'recent_5games_avg', 'recent_10games_avg', 'success_10days', 'success_10games']]
y_train = mlp_train.loc[:, ['result_y']]

X_test = mlp_test.loc[:, ['avg', 'slg', 'ops', 'home/away_avg_y', 'vs_ab', 'vs_hit', 'vs_avg', 'recent_5days_avg', 'recent_5games_avg', 'recent_10games_avg', 'success_10days', 'success_10games']]
y_test = mlp_test.loc[:, ['result_y']]

# %%
X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

# %%
number_of_train_samples = X_train.shape[0]
width = X_train.shape[1]
X_train = X_train.reshape(number_of_train_samples, width)

# %%
number_of_test_samples = X_test.shape[0]
X_test = X_test.reshape(number_of_test_samples, width)

# %%
X_train = minmax_scale(X_train, feature_range=(0,1), axis = 0)
X_test = minmax_scale(X_test, feature_range=(0,1), axis = 0)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()

model.add(Dense(512, input_dim= width, kernel_initializer = 'glorot_uniform', activation = 'relu'))
# model.add(Dropout(0.3))
model.add(Dense(300, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(256, kernel_initializer = 'glorot_uniform', activation = 'relu'))

model.add(Dense(128, kernel_initializer = 'glorot_uniform', activation = 'relu'))

model.add(Dense(64, kernel_initializer = 'glorot_uniform', activation = 'relu'))

model.add(Dense(32, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(16, kernel_initializer = 'glorot_uniform', activation = 'relu'))
model.add(Dense(2, activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs= 100, batch_size = 32)
# Out:
# Epoch 1/100
# 737/737 [==============================] - 18s 5ms/step - loss: 0.6479 - accuracy: 0.6755
# Epoch 2/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6305 - accuracy: 0.6747
# Epoch 3/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6313 - accuracy: 0.6733
# Epoch 4/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6292 - accuracy: 0.6760
# Epoch 5/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6319 - accuracy: 0.6722
# Epoch 6/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6316 - accuracy: 0.6722
# Epoch 7/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6296 - accuracy: 0.6747
# Epoch 8/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6250 - accuracy: 0.6803
# Epoch 9/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6253 - accuracy: 0.6794
# Epoch 10/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6267 - accuracy: 0.6769
# Epoch 11/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6205 - accuracy: 0.6832
# Epoch 12/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6278 - accuracy: 0.6727
# Epoch 13/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6305 - accuracy: 0.6659
# Epoch 14/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6224 - accuracy: 0.6747
# Epoch 15/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6207 - accuracy: 0.6743
# Epoch 16/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6200 - accuracy: 0.6726
# Epoch 17/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6150 - accuracy: 0.6777
# Epoch 18/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6142 - accuracy: 0.6765
# Epoch 19/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6140 - accuracy: 0.6832
# Epoch 20/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6149 - accuracy: 0.6834
# Epoch 21/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6139 - accuracy: 0.6819
# Epoch 22/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6136 - accuracy: 0.6838
# Epoch 23/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6137 - accuracy: 0.6815
# Epoch 24/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6140 - accuracy: 0.6830
# Epoch 25/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6153 - accuracy: 0.6784
# Epoch 26/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6098 - accuracy: 0.6840
# Epoch 27/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6156 - accuracy: 0.6804
# Epoch 28/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6097 - accuracy: 0.6862
# Epoch 29/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6100 - accuracy: 0.6805
# Epoch 30/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6111 - accuracy: 0.6827
# Epoch 31/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6099 - accuracy: 0.6831
# Epoch 32/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6056 - accuracy: 0.6869
# Epoch 33/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6060 - accuracy: 0.6874
# Epoch 34/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6085 - accuracy: 0.6847
# Epoch 35/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6097 - accuracy: 0.6828
# Epoch 36/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6032 - accuracy: 0.6883
# Epoch 37/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6009 - accuracy: 0.6912
# Epoch 38/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6017 - accuracy: 0.6916
# Epoch 39/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6002 - accuracy: 0.6897
# Epoch 40/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6071 - accuracy: 0.6887
# Epoch 41/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6079 - accuracy: 0.6852
# Epoch 42/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6079 - accuracy: 0.6835
# Epoch 43/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6021 - accuracy: 0.6886
# Epoch 44/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6062 - accuracy: 0.6864
# Epoch 45/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6032 - accuracy: 0.6892
# Epoch 46/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6038 - accuracy: 0.6878
# Epoch 47/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6029 - accuracy: 0.6850
# Epoch 48/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6028 - accuracy: 0.6871
# Epoch 49/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6049 - accuracy: 0.6877
# Epoch 50/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6035 - accuracy: 0.6907
# Epoch 51/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6015 - accuracy: 0.6891
# Epoch 52/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6033 - accuracy: 0.6867
# Epoch 53/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6052 - accuracy: 0.6848
# Epoch 54/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5997 - accuracy: 0.6901
# Epoch 55/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6019 - accuracy: 0.6884
# Epoch 56/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6053 - accuracy: 0.6843
# Epoch 57/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6021 - accuracy: 0.6882
# Epoch 58/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6007 - accuracy: 0.6882
# Epoch 59/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6042 - accuracy: 0.6827
# Epoch 60/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6033 - accuracy: 0.6862
# Epoch 61/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6037 - accuracy: 0.6852
# Epoch 62/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6007 - accuracy: 0.6896
# Epoch 63/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5971 - accuracy: 0.6946
# Epoch 64/100
# 737/737 [==============================] - 4s 6ms/step - loss: 0.5999 - accuracy: 0.6880
# Epoch 65/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6018 - accuracy: 0.6864
# Epoch 66/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6021 - accuracy: 0.6898
# Epoch 67/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6017 - accuracy: 0.6900
# Epoch 68/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6019 - accuracy: 0.6884
# Epoch 69/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5991 - accuracy: 0.6906
# Epoch 70/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5999 - accuracy: 0.6880
# Epoch 71/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6031 - accuracy: 0.6862
# Epoch 72/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6010 - accuracy: 0.6863
# Epoch 73/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5984 - accuracy: 0.6894
# Epoch 74/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5999 - accuracy: 0.6890
# Epoch 75/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6000 - accuracy: 0.6865
# Epoch 76/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6029 - accuracy: 0.6874
# Epoch 77/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6042 - accuracy: 0.6846
# Epoch 78/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6033 - accuracy: 0.6851
# Epoch 79/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5996 - accuracy: 0.6861
# Epoch 80/100
# 737/737 [==============================] - 4s 6ms/step - loss: 0.6010 - accuracy: 0.6885
# Epoch 81/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5978 - accuracy: 0.6908
# Epoch 82/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6001 - accuracy: 0.6890
# Epoch 83/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5984 - accuracy: 0.6869
# Epoch 84/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6010 - accuracy: 0.6872
# Epoch 85/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5985 - accuracy: 0.6891
# Epoch 86/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5984 - accuracy: 0.6886
# Epoch 87/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6055 - accuracy: 0.6838
# Epoch 88/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5984 - accuracy: 0.6916
# Epoch 89/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6017 - accuracy: 0.6891
# Epoch 90/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5963 - accuracy: 0.6926
# Epoch 91/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6002 - accuracy: 0.6809
# Epoch 92/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5924 - accuracy: 0.6953
# Epoch 93/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5999 - accuracy: 0.6883
# Epoch 94/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5934 - accuracy: 0.6934
# Epoch 95/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6006 - accuracy: 0.6868
# Epoch 96/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5983 - accuracy: 0.6856
# Epoch 97/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5960 - accuracy: 0.6916
# Epoch 98/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.5988 - accuracy: 0.6890
# Epoch 99/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6029 - accuracy: 0.6844
# Epoch 100/100
# 737/737 [==============================] - 4s 5ms/step - loss: 0.6021 - accuracy: 0.6850

# %%
loss_and_metrics = model.evaluate(X_test, y_test, batch_size = 32)
# Out:
# 185/185 [==============================] - 1s 2ms/step - loss: 0.6028 - accuracy: 0.6818

# %%
len(mlp_data[mlp_data['result_y'] ==1]) / len(mlp_data) * 100
# Out:
# 67.31950714503921
